# %% [markdown]
# # Random Uncertainty in Fitted Curves
#
# The PDF of these notes [can be found here](https://drive.google.com/open?id=1d-jqP9roe9fyMxrMRYvRXOOZPWsMu56J&usp=drive_fs).

# %%
# @title {display-mode: "form"}
## @markdown Run this cell to watch this video, and answer the questions below.
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = 'GUxu2CeLio0'
print(f'Video available at https://youtube.com/watch?v={video_id}')
#display_video(video_id, W=600, H=450)
# Out:
# Video available at https://youtube.com/watch?v=GUxu2CeLio0

# %% [markdown]
# <br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %%
# Importing support code
# @title
from urllib.request import urlretrieve

location = 'https://github.com/MAugspurger/ModSimPy_MAugs/raw/main/'
folder = 'Support_files/'
name = 'Embedded_Qs.ipynb'
local, _ = urlretrieve(location + folder + name, name)
# %run /content/$name
home = 'https://github.com/MAugspurger/Exper_Eng/raw/main/1_Measurement_and_Uncertainty/Embedded_Qs/'
efile = '2_f_Embedded_Qs'

#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,0)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# The aim of curve fitting is to find a "functional relationship" amongst the data points.  What does this mean?
#
# A) We want to find what the purpose of the data points is
# B) We want to the mean and standard deviation of the data points
# C) We want to find a mathematical function that approximates the data points
# D) We want to minimize the deviation between the data points

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,1)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Let's say you fit the data with the function f(x) = 5x^3 + 4x -10.  What order polynomial is this?
#
# A) First
# B) Second
# C) Third
# D) Fourth
# E) Fifth

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,2)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# "Deviation", a word that is part of the definition of "standard deviation", plays an important part in regresssion (that is, curve fitting).  What is the "deviation" of interest in regression analysis?
#
# A) The difference between the value of the curve at a given x and the y value of a data point at the same x
# B) The difference between the y value of a data point at a given x and the y value of the data point at the next higher x
# C) The difference between the value of the curve at a given x and the value of the curve at the next higher known x
# D) The sum of the y-direction differences between the curve and all the known data points

# %%
#@title #======================================= {form-width: "50%", display-mode: "form" }
#@markdown ##### *Quantitative Question* <br><br>Enter your answer, and run the cell to check your answer.  <br><br>
data = display_Quant(efile,home,3)
answer = None #@param {type:"number"}
check_Quant(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Let's say you test a load cell with standard masses at 1, 2, 3, and 4 kg and get a voltage readings of 0.55, 1.06,  1.71, and 2.09 V.  You find a linear fit, and get the function y = 0.55x.   Calculate the standard error of the fit manually and enter it here (in volts).

# %% [markdown]
# #=======================================
#
# <br>
#
# <center>
# <img src = https://github.com/MAugspurger/Exper_Eng/raw/main/1_Measurement_and_Uncertainty/Images/r_squared.PNG width = 700>
# </center>

# %%
#@title  { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,4)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Look at the two plots above, which represent measurements of the density of a gas at different temperatures.   Which best describes the characteristics of the fitted curve on the right compared to that on the left?
#
# A) The coefficient of determination (R-squared) on the right is closer to 1.0 and the standard error of the fit on the right is smaller
# B) The coefficient of determination (R-squared) on the right is closer to 1.0 and the standard error of the fit on the right is bigger
# C) The coefficient of determination (R-squared) on the right is closer to 0.0 and the standard error of the fit on the right is smaller
# D) The coefficient of determination (R-squared) on the right is closer to 0.0 and the standard error of the fit on the right is larger

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,5)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Remembering that the definition of the standard error of the fit is similar to standard deviation, what would be a good guess for the standard error of the fit for the plot on the right?
#
# A) 0.05
# B) 0.2
# C) 0.5
# D) 1.1
# E) 10.0

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>
