# %% [markdown]
# # 3c. Determining Uncertainty: Propagating Uncertainty

# %% [markdown]
# This is the first notebook on determining systematic and total uncertainty.
#
# <br>
#
# For a "hard copy" of the notes for unit 3 (Determining Uncertainty), [click here](https://drive.google.com/open?id=1sHs0VrP4MwfVHALXbm8lKFbR3aDp2I-v&usp=drive_fs)

# %%
# @title {display-mode: "form"}
## @markdown Run this cell to watch this video, and answer the questions below.
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = 'OMfFR-_fhrk'
print(f'Video available at https://youtube.com/watch?v={video_id}')
#display_video(video_id, W=600, H=450)
# Out:
# Video available at https://youtube.com/watch?v=OMfFR-_fhrk

# %% [markdown]
# <br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %%
# Importing support code
# @title
from urllib.request import urlretrieve

location = 'https://github.com/MAugspurger/ModSimPy_MAugs/raw/main/'
folder = 'Support_files/'
name = 'Embedded_Qs.ipynb'
local, _ = urlretrieve(location + folder + name, name)
# %run /content/$name
home = 'https://github.com/MAugspurger/Exper_Eng/raw/main/1_Measurement_and_Uncertainty/Embedded_Qs/'
efile = '3_b_c_Embedded_Qs'

#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,3)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# What problem does error propagation address?
#
# A) Sometimes we want the uncertainty in a measured value but have to way to determine what that is
# B) Sometimes we want the total uncertainty in a value that has both random and systematic uncertainties
# C) Sometimes we want the uncertainty in a value that is calculated by a measured value
# D) Sometimes we want to just close our eyes for a little while and not think about uncertianty

# %% [markdown]
# #=======================================
#
# <br>
#
# <center>
# <img src = https://github.com/MAugspurger/Exper_Eng/raw/main/1_Measurement_and_Uncertainty/Images/propagation.PNG width = 300>
# </center>

# %%
#@title { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Matching Question* <br><br>Enter the correct 'definition' letters, with a space in between each, in the order of the 'Terms'.  Run the cell to check your answer.  <br><br>
data, number = display_match(efile, home,4)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_match(data,a, number)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Above is the basic expression for error propagation.  Imagine you are measuring the width of box in order to find its volume.  You determine the uncertainty in the width, but need to propagate that to an uncertainty in the volume.  Match the terms below with their definition in this case.
#
# Terms
#
# 1) y
# 2) x
# 3) u_y
# 4) u_x
# 5) dy/dx
#
# Definitions
#
# A) The rate at which the volume changes as the width changes
# B) The rate at which the width changes as the volume changes
# C) The width of the box
# D) The volume of the box
# E) The uncertainty in the width
# F) The uncertainty in the volume

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,5)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# You are measuring the width W of a box to find its volume V with the equation V = WLH, where L and H are the height and length of the box.  What is the sensitivity of volume to width?
#
# A) WLH
# B) V/W
# C) WV
# D) LH

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,6)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Consider the following situations.  In which case would the final result be most "sensitive" to small changes in the measured value?
#
# A) The area A of square in response to the measurement L of one side (A = L^2)
# B) The radiative emissions from a surface E in response to the measurement of its temperature T (E = constant * T^4)
# C) The force F required to accelerate an object in response to the measurement of its mass (F = ma)

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>
