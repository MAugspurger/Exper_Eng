# %% [markdown]
# # Introduction to Standards

# %%
# @title {display-mode: "form"}
## @markdown Run this cell to watch this video, and answer the questions below.
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = 'Op7txLke9VY'
print(f'Video available at https://youtube.com/watch?v={video_id}')
#display_video(video_id, W=600, H=450)
# Out:
# Video available at https://youtube.com/watch?v=Op7txLke9VY

# %% [markdown]
# <br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %%
# Importing support code
# @title
from urllib.request import urlretrieve

location = 'https://github.com/MAugspurger/ModSimPy_MAugs/raw/main/'
folder = 'Support_files/'
name = 'Embedded_Qs.ipynb'
local, _ = urlretrieve(location + folder + name, name)
# %run /content/$name
home = 'https://github.com/MAugspurger/Exper_Eng/raw/main/1_Measurement_and_Uncertainty/Embedded_Qs/'
efile = '1_b_c_Embedded_Qs'

#@title { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Matching Question* <br><br>Enter the correct 'definition' letters, with a space in between each, in the order of the 'Terms'.  Run the cell to check your answer.  <br><br>
data, number = display_match(efile, home,8)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_match(data,a, number)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Match each situation ('term') with the word that best describes that situation ('definition').
#
# Terms
#
# 1) The government lists the detailed steps that must be taken every time a brake pad is tested
# 2) The government sets a maximum temperature that a brake pad can reach during an independent test in order to make that pad available to the public
# 3) A brake manufacturer sets a lower maximum temperature that its own brake pad can reach during its corporate tests
# 4) The government releases a set of rules defining the minimum requirements for brake pads
#
# Definitions
#
# A) Code
# B) Protocol
# C) Internal Standard
# D) Regulatory Standard

# %%
#@title { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Matching Question* <br><br>Enter the correct 'definition' letters, with a space in between each, in the order of the 'Terms'.  Run the cell to check your answer.  <br><br>
data, number = display_match(efile, home,9)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_match(data,a, number)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Match the desirable behavior/ outcome with justification for using standards
#
# Terms
#
# 1) A customer reads that a package of cookies has 180 calories, and can dependably know that this package has fewer calories than the package that says 220 calories
# 2) A exit door explodes from an airplane, but you know when your team decided which bolts to use, they were following regulatory standards
# 3) A city hired a contractor to build a bridge, but didn't open the bridge when an inspector noticed that the beams used were not up to the standard
# 4) You bought an off-brand charger for your iPhone, but it worked without any problems
# 5) A customer bought your company's refrigerator, which met the stringent internal standard for noise production, and was pleased with how quiet it was
#
# Definitions
#
# A) Liability
# B) Safety
# C) Interoperability
# D) Communication
# E) Reputation/ public trust

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>
