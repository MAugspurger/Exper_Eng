# %% [markdown]
# # 3b. Determining Uncertainty: Combining Uncertainties

# %% [markdown]
# This is the first notebook on determining systematic and total uncertainty.
#
# <br>
#
# For a "hard copy" of the notes for unit 3 (Determining Uncertainty), [click here](https://drive.google.com/open?id=1sHs0VrP4MwfVHALXbm8lKFbR3aDp2I-v&usp=drive_fs)

# %%
# @title {display-mode: "form"}
## @markdown Run this cell to watch this video, and answer the questions below.
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = '6m3cmq9P_n4'
print(f'Video available at https://youtube.com/watch?v={video_id}')
#display_video(video_id, W=600, H=450)
# Out:
# Video available at https://youtube.com/watch?v=6m3cmq9P_n4

# %% [markdown]
# <br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %% [markdown]
# <center>
# <img src = https://github.com/MAugspurger/Exper_Eng/raw/main/1_Measurement_and_Uncertainty/Images/quadrature.PNG width = 600>
# </center>

# %%
# Importing support code
# @title
from urllib.request import urlretrieve

location = 'https://github.com/MAugspurger/ModSimPy_MAugs/raw/main/'
folder = 'Support_files/'
name = 'Embedded_Qs.ipynb'
local, _ = urlretrieve(location + folder + name, name)
# %run /content/$name
home = 'https://github.com/MAugspurger/Exper_Eng/raw/main/1_Measurement_and_Uncertainty/Embedded_Qs/'
efile = '3_b_c_Embedded_Qs'

#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,0)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# When you combine constituent values in quadrature, what can we say about the magnitude (absolute value) of the resulting value?
#
# A) It will be larger than all of the constituent absolute values, but less than the sum of those values
# B) It will be larger than some of the constituent absolute values but smaller than others
# C) It will be smaller than all of the constituent absolute values
# D) The size of its value will depend on the signs of the constituent values
# E) It will be larger than the sum of the constituent absolute values

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,1)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Given your answer to the previous question, why is quadrature a reasonable method for combining uncertainties?
#
# A) Because the overall error will sometimes be more than the sum of all the individual errors
# B) Because if there are multiple errors, we can assume that the sign of the errors will sometimes be different but that the overall error will never be less than the biggest error
# C) Because we can assume that the sign of the errors will be different and so the overall error will be smaller than the biggest error

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,2)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# What role does professional judgment play in evaluating uncertainty?
#
# A) We should never add uncertainty that we cannot directly quantify
# B) We can decide to make the uncertainty smaller than our quantified number based on judgement, but not larger
# C) We can decide to make the uncertainty smaller or larger than our quantified number
# D) We can decide to make the uncertainty larger than our quantified number, but not smaller

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>
