# %% [markdown]
# # 2b. Random Error and Uncertainty: Understanding Standard Deviation

# %%
# @title {display-mode: "form"}
## @markdown Run this cell to watch this video, and answer the questions below.
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = 'KeMJPbjnbZw'
print(f'Video available at https://youtube.com/watch?v={video_id}')
#display_video(video_id, W=600, H=450)
# Out:
# Video available at https://youtube.com/watch?v=KeMJPbjnbZw

# %% [markdown]
# <br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %% [markdown]
# <center>
# <img src = https://github.com/MAugspurger/Exper_Eng/raw/main/1_Measurement_and_Uncertainty/Images/SDev_equation.PNG width = 300>
# </center>

# %%
# Importing support code
# @title
from urllib.request import urlretrieve

location = 'https://github.com/MAugspurger/ModSimPy_MAugs/raw/main/'
folder = 'Support_files/'
name = 'Embedded_Qs.ipynb'
local, _ = urlretrieve(location + folder + name, name)
# %run /content/$name
home = 'https://github.com/MAugspurger/Exper_Eng/raw/main/1_Measurement_and_Uncertainty/Embedded_Qs/'
efile = '2_a_b_Embedded_Qs'

#@title  { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,4)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Look at the equation for standard deviation.    What is a good "translation" for this equation?
#
# A) The average distance between the data points in a data set and the average value
# B) The average value of data points in a data set
# C) The sum of the values of the data points in a data set
# D) The square root of the average difference between the points in a data set and their average value

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,5)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Let's say I am measuring the mass of brake pads that come off an assembly line.  I find they have an average mass of 0.145 and a sigma value of 0.013.  If I want to be 95% sure that the next one off the line will fall within my uncertainty range, what should my uncertainty be?
#
# A) 0.0065
# B) 0.01235
# C) 0.013
# D) 0.026
# E) 0.039

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,6)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# You take data on the average voltage of a set of batteries, and find an average value of V=9.15 volts, with a standard deviation of 0.36.  You take the reading from one more battery, and find a voltage of 9.33.  What is the z-score of this new reading?
#
# A) 0.18
# B) 0.5
# C) 0.36
# D) 1.019
# E) 2.0

# %% [markdown]
# #=======================================
#
# Here is the link to the [z-score calculator](https://www.calculator.net/z-score-calculator.html) that you can use to answer the next two questions.

# %%
#@title {form-width: "50%", display-mode: "form" }
#@markdown ##### *Quantitative Question* <br><br>Enter your answer, and run the cell to check your answer.  <br><br>
data = display_Quant(efile,home,7)
answer = None #@param {type:"number"}
check_Quant(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# You take data on the average voltage of a set of batteries, and find an average value of V=9.15 volts, with a standard deviation of 0.36.  What is the probability that the next battery you check will have a value within 0.5 volts of 9.15?  Use a z-score calculator to find the answer (see the link above).  Enter your answer as a whole number percentage (for example, "12" for 12.3%)

# %%
#@title #======================================= {form-width: "50%", display-mode: "form" }
#@markdown ##### *Quantitative Question* <br><br>Enter your answer, and run the cell to check your answer.  <br><br>
data = display_Quant(efile,home,8)
answer = None #@param {type:"number"}
check_Quant(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# You take data on the average voltage of a set of batteries, and find an average value of V=9.15 volts, with a standard deviation of 0.36.   What would be the uncertainty with  a confidence level of 75%? (answer in volts)

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,9)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# You take data on the average voltage of a set of 16 batteries, and find an average value of V=9.15 volts, with a standard deviation of 0.36.   You then find 2 new data points: A) a single measurement of 1 new battery B) the mean value of   16 new batteries.  Which would you expect to fall closer (on average) to 9.15?
#
# A) The measurement of the single battery would be closer
# B) The mean value of the measurements of 16 new batteries would be closer
# C) You would expect them to be equally distant (on average) from 9.15

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,10)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# You take data on the average voltage of a set of 16 batteries, and find an average value of V=9.15 volts, with a standard deviation of 0.36.   What is the uncertainty in the mean value at a 95% confidence level?  Use the standard deviation of the mean to find this.
#
# A) 0.0225
# B) 0.09
# C) 0.18
# D) 0.36
# E) 0.72
# F) 1.44

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>
