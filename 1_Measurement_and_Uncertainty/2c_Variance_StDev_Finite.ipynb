# %% [markdown]
# # 2c. Random Error and Uncertainty: Using Standard Deviation with Small Data Sets

# %%
# @title {display-mode: "form"}
## @markdown Run this cell to watch this video, and answer the questions below.
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = '1TdOiqX-f8w'
print(f'Video available at https://youtube.com/watch?v={video_id}')
#display_video(video_id, W=600, H=450)
# Out:
# Video available at https://youtube.com/watch?v=1TdOiqX-f8w

# %% [markdown]
# <br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %%
# Importing support code
# @title
from urllib.request import urlretrieve

location = 'https://github.com/MAugspurger/ModSimPy_MAugs/raw/main/'
folder = 'Support_files/'
name = 'Embedded_Qs.ipynb'
local, _ = urlretrieve(location + folder + name, name)
# %run /content/$name
home = 'https://github.com/MAugspurger/Exper_Eng/raw/main/1_Measurement_and_Uncertainty/Embedded_Qs/'
efile = '2_c_d_Embedded_Qs'

#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*True or False* <br><br>

answer = "" # @param ["", "True", "False"]
data = display_TF(efile,home,answer,0)
check_TF(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# You take two sets of data.  The first set A has 60 data points, and the second set B has 10 data points, but they have a similar scatter and central tendency.  True or False: Set B will have a larger standard deviation
#
# Enter your answer in the dropdown box.

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*True or False* <br><br>

answer = "" # @param ["", "True", "False"]
data = display_TF(efile,home,answer,1)
check_TF(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# You take two sets of data.  The first set A has 60 data points, and the second set B has 10 data points, but they have a similar scatter and central tendency.  True or False: Set B will have a larger standard deviation of the mean
#
# Enter your answer in the dropdown box.

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*True or False* <br><br>

answer = "" # @param ["", "True", "False"]
data = display_TF(efile,home,answer,2)
check_TF(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# You take two sets of data.  The first set A has 60 data points, and the second set B has 10 data points, but they have a similar scatter and central tendency.   True or False: Set B will have a larger "t-score".
#
# Enter your answer in the dropdown box.

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*True or False* <br><br>

answer = "" # @param ["", "True", "False"]
data = display_TF(efile,home,answer,3)
check_TF(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# You take two sets of data.  The first set A has 60 data points, and the second set B has 10 data points, but they have a similar scatter and central tendency.  True or False: If you take one more data point, the probability that a new single data point will land within a standard deviation of the mean is smaller for set B.
#
# Enter your answer in the dropdown box.

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*True or False* <br><br>

answer = "" # @param ["", "True", "False"]
data = display_TF(efile,home,answer,4)
check_TF(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# You take two sets of data.  The first set A has 60 data points, and the second set B has 10 data points, but they have a similar scatter and central tendency.  True or False: The mean value for set B will have a larger uncertainty
#
# Enter your answer in the dropdown box.

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,5)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# How many data points do you need to have "t" essentially equal to "z"?  In other words, how many data points before adding more data points will not significantly improve your confidence level?
#
# A) 5
# B) 10
# C) 20
# D) 60
# E) 200

# %% [markdown]
# #=======================================
#
# Here is the link to the [t-score calculator](https://homepage.divms.uiowa.edu/~mbognar/applets/t.html) that you can use to answer the next two questions.

# %%
#@title {form-width: "50%", display-mode: "form" }
#@markdown ##### *Quantitative Question* <br><br>Enter your answer, and run the cell to check your answer.  <br><br>
data = display_Quant(efile,home,6)
answer = None #@param {type:"number"}
check_Quant(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# You are measuring the height of the tallest man on earth.  With a ladder.  You take 14 measurements of his height, and have a standard deviation of 17.2 mm.  You want to have a confidence level of 90%.  What is the t-score in this situation?  Use the t-score calculator directly above this question.

# %%
#@title #======================================= {form-width: "50%", display-mode: "form" }
#@markdown ##### *Quantitative Question* <br><br>Enter your answer, and run the cell to check your answer.  <br><br>
data = display_Quant(efile,home,7)
answer = None #@param {type:"number"}
check_Quant(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# You are measuring the height of the tallest woman on earth.  Also with a ladder.  You take 4 measurements of her height, and have a standard deviation of 14.0 mm.  You want to have a confidence level of 95%.  What is the uncertainty in the mean value of your measurement (in mm)?

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>
