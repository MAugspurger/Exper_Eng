# %% [markdown]
# # 2a. Random Error and Uncertainty: Describing Variance
#
# For a "hard copy" of the notes, here is a link to a PDF of [the notes for the second unit, which focuses on random error and uncertainty](https://drive.google.com/open?id=1VawrRiCLLqh1zFuua38CF-P56SWaPiFJ&usp=drive_fs)

# %%
# @title {display-mode: "form"}
## @markdown Run this cell to watch this video, and answer the questions below.
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = 'Vs2D8_Y1qDg'
print(f'Video available at https://youtube.com/watch?v={video_id}')
#display_video(video_id, W=600, H=450)
# Out:
# Video available at https://youtube.com/watch?v=Vs2D8_Y1qDg

# %% [markdown]
# <br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %%
# Importing support code
# @title
from urllib.request import urlretrieve

location = 'https://github.com/MAugspurger/ModSimPy_MAugs/raw/main/'
folder = 'Support_files/'
name = 'Embedded_Qs.ipynb'
local, _ = urlretrieve(location + folder + name, name)
# %run /content/$name
home = 'https://github.com/MAugspurger/Exper_Eng/raw/main/1_Measurement_and_Uncertainty/Embedded_Qs/'
efile = '2_a_b_Embedded_Qs'

#@title { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Matching Question* <br><br>Enter the correct 'definition' letters, with a space in between each, in the order of the 'Terms'.  Run the cell to check your answer.  <br><br>
data, number = display_match(efile, home,0)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_match(data,a, number)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Determine whether the situation described is an instance of systematic error or random error.
#
# Terms
#
# 1) You are measuring an average wnid speed, and the data includes not only the mean value but periodic gusts complicate the data
# 2) You are measuring the mass of bags of fruit, but neglect to subtract the mass of the hanger from the data
# 3) You are measuring the voltage from a force sensor, but the alternating current from your power source is included in the voltage readings
# 4) You are measuring the temperature of a roast, and want the temperature at the center (the coolest part of the roast), but it is difficult to determine when the probe is exactly in the center
#
# Definitions
#
# A) Systematic
# B) Random

# %%
#@title #============================= { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Matching Question* <br><br>Enter the correct 'definition' letters, with a space in between each, in the order of the 'Terms'.  Run the cell to check your answer.  <br><br>
data, number = display_match(efile, home,1)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_match(data,a, number)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Match the term with the correct definition (note that some definitions match more than one term)
#
# Terms
#
# 1) Histogram
# 2) Probability density function
# 3) Central tendency
# 4) Gaussian distribution
# 5) Bin Plot
# 6) Normal distribution
# 7) Bell Curve
# 8) Scatter
#
# Definitions
#
# A) A mathematical function that describes a large cluster of data points around a mean value and a "tail" of data points that gets thinner as the value gets farther from the mean.
# B) A general term that describes a data set in which most of the data points are clustered around a mean value
# C) A type of bar plot in which each bar represents the number of data points that fall between an lower and upper limit.
# D) A type of plot in which a continuous line shows the percentage chance that a new data point would have that value.
# E) The tendency of data points to vary randomly from an average value

# %% [markdown]
# #=============================

# %% [markdown]
# <center>
# <img src = https://github.com/MAugspurger/Exper_Eng/raw/main/1_Measurement_and_Uncertainty/Images/Gaussian_curves.PNG width = 400>
# </center>

# %%
#@title {form-width: "50%", display-mode: "form" }
#@markdown ##### *Quantitative Question* <br><br>Enter your answer, and run the cell to check your answer.  <br><br>
data = display_Quant(efile,home,2)
answer = None #@param {type:"number"}
check_Quant(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Look at the two plots above.  Both show Gaussian distributions; the Gaussian equation is shown on the top plot.   The sigma and x_bar values of the top plot are shown.  What is the x_bar value of the plot on the right (approximately)?

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,3)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Look at the two plots above.  Both show Gaussian distributions; the Gaussian equation is shown on the top plot.   The sigma and x_bar values of the top plot are shown.  Which of these is a possible value for the sigma of the lower plot?
#
# A) 0.2
# B) 0.5
# C) 1.5

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>
