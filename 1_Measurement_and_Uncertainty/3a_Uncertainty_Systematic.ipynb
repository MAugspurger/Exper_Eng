# %% [markdown]
# # 3a. Determining Uncertainty: Systematic Uncertainty

# %% [markdown]
# This is the first notebook on determining systematic and total uncertainty.
#
# <br>
#
# For a "hard copy" of the notes for unit 3 (Determining Uncertainty), [click here](https://drive.google.com/open?id=1sHs0VrP4MwfVHALXbm8lKFbR3aDp2I-v&usp=drive_fs)

# %%
# @title {display-mode: "form"}
## @markdown Run this cell to watch this video, and answer the questions below.
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = '3KITS_6hoz8'
display_video(video_id, W=600, H=450)

# %% [markdown]
# <br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %%
# Importing support code
# @title
from urllib.request import urlretrieve

location = 'https://github.com/MAugspurger/ModSimPy_MAugs/raw/main/'
folder = 'Support_files/'
name = 'Embedded_Qs.ipynb'
local, _ = urlretrieve(location + folder + name, name)
# %run /content/$name
home = 'https://github.com/MAugspurger/Exper_Eng/raw/main/1_Measurement_and_Uncertainty/Embedded_Qs/'
efile = '3_a_Embedded_Qs'

#@title #======================================= { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Multiple Answer Question* <br><br>Enter the all the correct letters, with a space in between each, and run the cell to check your answer.  <br><br>
data = display_multAns(efile, home,0)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_multAns(data,a)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# In our viscosity lab, we use a zahn cup to measure viscosity, and measure the temperature of the oil as we are testing the oil.  Which of the following could be a possible extraneous variable?  Submit all that are true.
#
# A) The air pressure in the room
# B) Dirt or dust on the zahn cup
# C) The speed with which we remove the zahn cup from the sample
# D) The thermal layering of the oil in the sample (that is, lower temperature oil sinking to the bottom of the sample)

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,1)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# What does it mean to "control" for a variable whose effect we are not studying?  As an example, consider air pressure in the boiling point experiment in the notes.
#
# A) To control for pressure, we would want to make sure it is the same for each experiment
# B) To control for pressure, we would want to adjust our calculations to include the effects of pressure
# C) To control for pressure, we would want to increase the uncertainty values for our conclusions about boiling points
# D) Both of the above answers are ways of controlling for a variable

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>

# %%
# @title {display-mode: "form"}
## @markdown Run this cell to watch this video, and answer the questions below.
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = 'RhUzONmK2wA'
display_video(video_id, W=600, H=450)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# <br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %%
#@title { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,2)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Imagine you have a load cell that is rated for 0-50 kg, and you use the sensitivity K (in units kg/volt) in the manufacturer's data sheet.  You measure a set of masses that range from 45-53 kg, and experience some error, particularly in the larger masses.  What kind of error might this be?
#
# A) Linearity
# B) Sensitivity
# C) Shift
# D) Hysteresis

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,3)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Imagine you are calibrating a load cell.  You add a series of masses to the cell, and record the voltages.  You then remove these weights gradually and record the voltages on the "way down."  You find that the second set of readings are all a bit higher than the first set that you took on the "way up".  What kind of error is this?
#
# A) Linearity
# B) Sensitivity
# C) Shift
# D) Hysteresis

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,4)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Imagine you are calibrating a load cell.  You take measurements for 10 masses, plot them, and fit a linear curve to the plots.   The fitted curve matches your data points pretty well, but the y-intercept of the fitted curve is not 0: that is, when the load cell has no load, it still produces a non-zero response.  What kind of error is this?
#
# A) Linearity
# B) Sensitivity
# C) Shift
# D) Hysteresis

# %%
#@title #======================================= { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Multiple Answer Question* <br><br>Enter the all the correct letters, with a space in between each, and run the cell to check your answer.  <br><br>
data = display_multAns(efile, home,5)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_multAns(data,a)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Calibration seems like the perfect solution to systematic error: if we calibrate our instrument, we know exactly what the output of the instrument is for a given input.  But why is calibration not "perfect"?   Submit all that are true.
#
# A) The "standards" that we use might not be perfectly accurate
# B) Our calibration process might contain random error
# C) Our calibration process might contain systematic error

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>
