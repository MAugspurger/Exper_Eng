# %% [markdown]
# # Signal Processing

# %% [markdown]
# A dynamic signal contains a bucketload of information.  So often times we want to *process* that signal (or *condition* it) so that the information we want is more accessible.  This notebook dives into a couple of the common ways to do this.
#
# <br>
#
# <center>
# <img src = https://github.com/MAugspurger/Exper_Eng/raw/main/2_Signals/Images/bucket.PNG width = 300>
# </center>
#
# <br>
#
# If you would like a "hard copy" of Signal notes, here is a link to a PDF of [the notes for the Signal notebooks](https://drive.google.com/open?id=1i_yLZW9c8w0E6jpeVFqcRcltuAtYjOJU&usp=drive_fs)

# %%
# @title {display-mode: "form"}
## @markdown Run this cell to watch this video, and answer the questions below.
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = 'kiIzQh_oTZM'
display_video(video_id, W=600, H=450)

# %% [markdown]
# <br><br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %% [markdown]
# <center>
# <img src = https://github.com/MAugspurger/Exper_Eng/raw/main/2_Signals/Images/hi_filter.PNG width = 400>
# </center>

# %%
# Importing support code
# @title
from urllib.request import urlretrieve

location = 'https://github.com/MAugspurger/ModSimPy_MAugs/raw/main/'
folder = 'Support_files/'
name = 'Embedded_Qs.ipynb'
local, _ = urlretrieve(location + folder + name, name)
# %run /content/$name
home = 'https://github.com/MAugspurger/Exper_Eng/raw/main/2_Signals/Embedded_Qs/'
efile = '2_2_Embedded_Qs'

#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,0)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# In the image above, what kind of filter has the blue signal been put through in order to produce the orange signal?
#
# A) Low pass filter
# B) High pass filter

# %%
#@title #======================================= { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Matching Question* <br><br>Enter the correct 'definition' letters, with a space in between each, in the order of the 'Terms'.  Run the cell to check your answer.  <br><br>
data, number = display_match(efile, home,1)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_match(data,a, number)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Below are some reasons that an experimental signal might have a high frequency signal laid on top of a low frequency signal?  Decide whether you'd want keep that high frequency "noise" or filter it out.
#
# Terms
#
# 1) Vibrations in the sensor
# 2) Oscillations in the source voltage
# 3) Random changes in the quantity itself (like the velocity in a swirling wind)
# 4) The presence of two processes in the measured quantity (an ocean wave that has large scale swells and small scale surface wind waves)
#
# Definitions
#
# A) Filter (or average) it out!
# B) Might want to keep that high frequency data

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>

# %% [markdown]
# <br>
#
# <center>
# <img src = https://github.com/MAugspurger/Exper_Eng/raw/main/2_Signals/Images/popcorn.PNG width = 400>
# </center>
#
# <br>

# %%
# @title {display-mode: "form"}
## @markdown Run this cell to watch this video, and answer the questions below.
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = 'kbseoW1Y3Wg'
display_video(video_id, W=600, H=450)

# %% [markdown]
# <br><br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %%
#@title { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Matching Question* <br><br>Enter the correct 'definition' letters, with a space in between each, in the order of the 'Terms'.  Run the cell to check your answer.  <br><br>
data, number = display_match(efile, home,2)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_match(data,a, number)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Match the  definition to the term
#
# Terms
#
# 1) A form of representation of a dynamic signal that plots the overall amplitude of the signal as function of time
# 2) A problem that arises in fourier analysis if the sample of the signal is not sufficiently long
# 3) A mathematical operation that moves a representation of a signal from the time to frequency domain
# 4) A form of representation of a dynamic signal that displays strength of the simple signals that make up the complex signal
# 5) The smallest gap between frequencies that can be represented in a given Fourier analysis
#
# Definitions
#
# A) Frequency resolution
# B) Fourier transform
# C) Frequency domain
# D) Time domain
# E) Attenuation

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,3)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# What is on the x-axis of a frequency domain plot?
#
# A) Time (in s)
# B) Frequency (in Hz)
# C) Amplitude (in volts)
# D) Time (in Hz)
# E) Frequency (in s)

# %% [markdown]
# #=======================================
#
# <br>
#
# <center>
# <img src = https://github.com/MAugspurger/Exper_Eng/raw/main/2_Signals/Images/time_domain.PNG width = 600>
# </center>
#
# <br>

# %%
#@title { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,4)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Look at the time domain signal above.  Which of the frequency domain plots represents the same signal?
#
# A) A
# B) B
# C) C

# %% [markdown]
# #=======================================
#
# <br>
#
# <center>
# <img src = https://github.com/MAugspurger/Exper_Eng/raw/main/2_Signals/Images/freq_domain.PNG width = 400>
# </center>
#
# <br>

# %%
#@title { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,5)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Look at the frequency domain plot above.   Which of the time domain plots represents the same signal?
#
# A) A
# B) B
# C) C

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>
